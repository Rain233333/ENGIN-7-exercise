# %% [markdown]
# 1. Print "I love Python" using Python Shell.

# %%
print('I love Python')
# Out:
# I love Python

# %% [markdown]
# 2. Print "I love Python" by typing it into a .py file and run it from command line.

# %%
print('I love Python')
# Out:
# I love Python

# %% [markdown]
# 3. Type import antigravity in the Ipython Shell, it will take you to xkcd and see the awesome Python.

# %%
import antigravity

# %% [markdown]
# 4. Launch a new Jupyter notebook server in a folder called "excercis" and create a new Python notebook with the name "excercis_1", then you can do the rest of the problems within this notebook.

# %%
print('')

# %% [markdown]
# 5. Compute the area of a triangle with base 10 and height 12. Recall that the area of a triangle is half the base times the height.

# %%
base = 10
height = 12
area_of_triangle = 0.5 * base * height
print(area_of_triangle)
# Out:
# 60.0

# %% [markdown]
# 6. Compute the surface area and volume of a cylinder with radius 5 and height 3.

# %%
import math
radius = 5
height = 3
surface_area = 2 * math.pi * pow(radius, 2) + 2 * math.pi * radius * height
volume = math.pi * pow(radius, 2) * height
print(surface_area)
print(volume)
# Out:
# 251.32741228718345
# 235.61944901923448

# %% [markdown]
# 7. Compute the slope between the points $(3,4)$ and $(5,9)$. Recall that the slope between points $(x_1, y_1)$ and $(x_2, y_2)$ is $\frac{y_2 - y_1}{x_2 - x_1}$.

# %%
point_1 = (3, 4)
point_2 = (5, 9)
slope = (point_1[1] - point_2[1]) / (point_1[0] - point_2[0])
print(slope)
# Out:
# 2.5

# %% [markdown]
# 8. Compute the distance between the points $(3,4)$ and $(5,9)$. Recall that the distance between points in two dimensions is $\sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$.

# %%
point_1 = (3, 4)
point_2 = (5, 9)
distance = math.sqrt(pow(point_2[0] - point_1[0], 2) + pow(point_2[1] - point_2[1], 2))
print(distance)
# Out:
# 2.0

# %% [markdown]
# 9. Use Python's factorial function to compute $6!$

# %%
print(math.factorial(6))
# Out:
# 720

# %% [markdown]
# > 10. ***A year is considered to be 365 days long. However, a more exact figure is 365.24 days. As a consequence, if we held to the standard 365-day year, we would gradually lose that fraction of the day over time, and seasons and other astronomical events would not occur as expected. A leap year is a year that has an extra day, February 29, to keep the timescale on track. Leap years occur on years that are exactly divisible by 4, unless it is exactly divisible by 100, unless it is divisible by 400. For example, the year 2004 is a leap year, the year 1900 is not a leap year, and the year 2000 is a leap year.***
#
# Compute the number of leap years between the years 1500 and 2010.

# %%
count = sum(1 for year in range(1500, 2011) if (year % 4 == 0) and (year % 100 != 0 or year % 400 ==0))
print(count)
# Out:
# 124

# %% [markdown]
# > 11. A very powerful approximation for $\pi$ was developed by a brilliant mathematician named Srinivasa Ramanujan. The approximation is the following:
# $$\frac{1}{\pi} \approx \frac{2\sqrt{2}}{9801} \sum_{k=0}^{N} \frac{(4k)!(1103+26390k)}{(k!)^4 396^{4k}}$$
#
# Use Ramanujan's formula for $N = 0$ and $N = 1$ to approximate $\pi$. Be sure to use format long. Compare your approximation with Python's stored value for pi. Hint: $0! = 1$ by definition.

# %%
import math
for N in range(2):
    print(f'N = {N}:')
    series_terms = [(math.factorial(4 * k) * (1103 + 26390 * k)) / (pow(math.factorial(k), 4) * pow(396, 4 * k)) for k in range(N + 1)]
    series_sum = math.fsum(terms)

    approx_pi = 1 / ((2 * math.sqrt(2) / 9801) * series_sum)
    
    print(f'Approximation for pi = {approx_pi}')
    print(f'Python\'s stored value for pi = {math.pi}')
# Out:
# N = 0:
# Approximation for pi = 3.1415926535897936
# Python's stored value for pi = 3.141592653589793
# N = 1:
# Approximation for pi = 3.1415926535897936
# Python's stored value for pi = 3.141592653589793

# %% [markdown]
# 12. The hyperbolic $\sin$ or $\sinh$ is defined in terms of exponentials as $\sinh(x) = \frac{\exp(x)-\exp(-x)}{2}$.
#
# Compute $\sinh$ for $x = 2$ using exponentials. Verify that the result is indeed the hyperbolic $\sin$ using Python's function $\sinh$ in the math module.

# %%
import math
x = 2
sinh_exp = ((math.exp(x) - math.exp(-x)) / 2)

print(f'sinh_exp: {sinh_exp}')
print(f'Python\'s sinh: {math.sinh(x)}')
# Out:
# sinh_exp: 3.626860407847019
# Python's sinh: 3.6268604078470186

# %% [markdown]
# 13. Verify that $\sin^2(x) + \cos^2(x) = 1$ for $x = \pi, \frac{\pi}{2}, \frac{\pi}{4}, \frac{\pi}{6}$.

# %%
import math

denominators = [1, 2, 4, 6]

for denominator in denominators:
    print(math.sin(math.pi / denominator) ** 2 + math.cos(math.pi / denominator) ** 2)
# Out:
# 1.0
# 1.0
# 1.0
# 1.0

# %% [markdown]
# 14. Compute the $\sin 87^\circ$.

# %%
import math
print(math.sin(87 * math.pi / 180))
# Out:
# 0.9986295347545738

# %% [markdown]
# 15. Write a Python statement that generates the following error:
# "AttributeError: module 'math' has no attribute 'sni'"
#
# Hint: sni is a misspelling of the function $\sin$.

# %%
import math
print(math.sni(math.pi))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import math
# ----> 2 print(math.sni(math.pi))
#
# AttributeError: module 'math' has no attribute 'sni'

# %% [markdown]
# 16. Write a Python statement that generates the following error:
# "TypeError: sin() takes exactly one argument (0 given)"
#
# Hint: Input arguments refers to the input of a function (any function); for example, the input in $\sin(\pi/2)$ is $\pi/2$.

# %%
import math
print(math.sin())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import math
# ----> 2 print(math.sin())
#
# TypeError: math.sin() takes exactly one argument (0 given)

# %% [markdown]
# 17. If $P$ is a logical expression, the law of noncontradiction states that $P \text{ AND } (\text{NOT } P)$ is always false. Verify this for $P$ true and $P$ false.

# %%
print(True and (not True))
print(False and (not False))
# Out:
# False
# False

# %% [markdown]
# 18. Let $P$ and $Q$ be logical expressions. De Morgan's rule states that $\text{NOT } (P \text{ OR } Q) = (\text{NOT } P) \text{ AND } (\text{NOT } Q)$ and $\text{NOT } (P \text{ AND } Q) = (\text{NOT } P) \text{ OR } (\text{NOT } Q)$. Generate the truth tables for each statement to show that De Morgan's rule is always true.

# %%
P = True
Q = True
print((not (P or Q)) == ((not P) and (not Q)))
print((not (P and Q)) == ((not P) or (not Q)))
# Out:
# True
# True

# %% [markdown]
# 19. Under what conditions for $P$ and $Q$ is $(P \text{ AND } Q) \text{ OR } (P \text{ AND } (\text{NOT } Q))$ false?

# %%
P = False
Q = False
print((P and Q) or (P and not Q))
# Out:
# False

# %% [markdown]
# 20. Construct an equivalent logical expression for OR using only AND and NOT.

# %% [markdown]
# 21. Construct an equivalent logical expression for AND using only OR and NOT.

# %% [markdown]
# 22. The logical operator XOR has the following truth table:
# Construct an equivalent logical expression for XOR using only AND, OR, and NOT that has the same truth table (see the following figure)
#
# | P \ Q | 1 | 0 |
# | :---: | :---: | :---: |
# | **1** | 0 | 1 |
# | **0** | 1 | 0 |

# %% [markdown]
# Bonus 1. Do the following calculation at the Python command prompt.
# $$e^2 \sin(\pi/6) + \log_e(3) \cos(\pi/9) - 5^3$$

# %% [markdown]
# Bonus 2. Do the following logical and comparison operations at the Python command prompt. You may assume that P and Q are logical expressions.
# For P = 1 and Q = 1; Compute $\text{NOT}(P) \text{ AND } \text{NOT}(Q)$.
# For a = 10 and b = 25; Compute $(a < b) \text{ AND } (a = b)$.
